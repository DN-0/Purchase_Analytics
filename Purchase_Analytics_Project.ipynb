# %% [markdown]
# # **Purchase Analytics**

# %% [markdown]
# # **Dataset**

# %% [markdown]
# The dataset contains purchase data for 500 customers at one store location for 2 years. The data is already preprocessed, since the focus in on purchase analytics.

# %% [markdown]
# ID - Unique customer id
#
# Day - Day when the customer visited the shop.
#
# Incidence - If the customer purchased (1) or not (0) an item from the category of interest.
#
# Brand - Which brand the customer has purchased (0 = No brand, 1->5 = Brand id).
#
# Quantity - Number of items bought
#
# Last_Inc_Brand - Shows which brand the customer has purchased on their previous store visit.
#
#
# Last_Inc_Quantity - Number of items bought by the customer from the product category of interest during their previous store visit.
#
# Price 1->5 - Price of an item from Brand 1->5 on a particular day.
#
# Promotion 1->5  Indicates whether Brand 1->5 was (1) or wasn't (0) on promotion on a particular day.
#
# Sex - Biological sex of customer, male = 0, female=1.
#
# Marital Status - 0 if single, 1 if married/divorced/separated/widowed.
#
# Age - Age of customer, from 18 to 75.
#
# Education - Level of education, 0 other/unknown, 1 high school, 2 uni, 3 graduate.
#
# Income - Self reported income of customer, 38k min, 309k max.
#
# Occupation - Category of occupation of the customer.
#
# Settlement size - Size of the city the customer lives in.

# %% [markdown]
# # **Import libraries, packages and dataset**

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import pickle

from sklearn.linear_model import LogisticRegression

# %%
df_purchase=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Purchase Analytics/Purchase_Analytics_1/purchase data.csv')

# %%
df_purchase
# Out:
#               ID  Day  Incidence  Brand  Quantity  Last_Inc_Brand  \
# 0      200000001    1          0      0         0               0
# 1      200000001   11          0      0         0               0
# 2      200000001   12          0      0         0               0
# 3      200000001   16          0      0         0               0
# 4      200000001   18          0      0         0               0
# ...          ...  ...        ...    ...       ...             ...
# 58688  200000500  703          0      0         0               2
# 58689  200000500  710          0      0         0               0
# 58690  200000500  717          0      0         0               0
# 58691  200000500  722          1      2         3               0
# 58692  200000500  726          0      0         0               2
#
#        Last_Inc_Quantity  Price_1  Price_2  Price_3  ...  Promotion_3  \
# 0                      0     1.59     1.87     2.01  ...            0
# 1                      0     1.51     1.89     1.99  ...            0
# 2                      0     1.51     1.89     1.99  ...            0
# 3                      0     1.52     1.89     1.98  ...            0
# 4                      0     1.52     1.89     1.99  ...            0
# ...                  ...      ...      ...      ...  ...          ...
# 58688                  1     1.41     1.85     2.01  ...            1
# 58689                  0     1.36     1.84     2.09  ...            0
# 58690                  0     1.50     1.80     2.14  ...            0
# 58691                  0     1.51     1.82     2.09  ...            0
# 58692                  1     1.51     1.82     2.09  ...            0
#
#        Promotion_4  Promotion_5  Sex  Marital status  Age  Education  Income  \
# 0                0            0    0               0   47          1  110866
# 1                0            0    0               0   47          1  110866
# 2                0            0    0               0   47          1  110866
# 3                0            0    0               0   47          1  110866
# 4                0            0    0               0   47          1  110866
# ...            ...          ...  ...             ...  ...        ...     ...
# 58688            0            0    0               0   42          1  120946
# 58689            0            0    0               0   42          1  120946
# 58690            0            0    0               0   42          1  120946
# 58691            0            0    0               0   42          1  120946
# 58692            0            0    0               0   42          1  120946
#
#        Occupation  Settlement size
# 0               1                0
# 1               1                0
# 2               1                0
# 3               1                0
# 4               1                0
# ...           ...              ...
# 58688           1                0
# 58689           1                0
# 58690           1                0
# 58691           1                0
# 58692           1                0
#
# [58693 rows x 24 columns]

# %%
# Check if there are null values.
df_purchase.isnull().sum()
# Out:
# ID                   0
# Day                  0
# Incidence            0
# Brand                0
# Quantity             0
# Last_Inc_Brand       0
# Last_Inc_Quantity    0
# Price_1              0
# Price_2              0
# Price_3              0
# Price_4              0
# Price_5              0
# Promotion_1          0
# Promotion_2          0
# Promotion_3          0
# Promotion_4          0
# Promotion_5          0
# Sex                  0
# Marital status       0
# Age                  0
# Education            0
# Income               0
# Occupation           0
# Settlement size      0
# dtype: int64

# %% [markdown]
# # **Data Segmentation Model**

# %% [markdown]
# ### **Segmentation steps:**
# 1. Standardize - using StandardScaler.
# 2. PCA - use PCA to transform the 7 geodemographical features into 3 principal components.
# 3. K-means PCA - feed the 3 principal components to the K means model to determine the segment.

# %% [markdown]
# ### **Import Segmentation Model**

# %%
scaler=pickle.load(open('/content/drive/MyDrive/Colab Notebooks/Purchase Analytics/Purchase_Analytics_1/scaler.pickle','rb'))

# %%
pca=pickle.load(open('/content/drive/MyDrive/Colab Notebooks/Purchase Analytics/Purchase_Analytics_1/pca.pickle','rb'))

# %%
kmeans_pca=pickle.load(open('/content/drive/MyDrive/Colab Notebooks/Purchase Analytics/Purchase_Analytics_1/kmeans_pca.pickle','rb'))

# %% [markdown]
# ### **Standardizing data**

# %% [markdown]
# We will not fit the scaler and the PCA objects, we will just transform the data using them.

# %%
# Add column names to a list named 'features'.
features=df_purchase[['Sex', 'Marital status','Age','Education','Income','Occupation','Settlement size']]

# Standardized data
df_purchase_segm_std=scaler.transform(features)

# %% [markdown]
# ### **PCA**

# %%
# Use PCA transform on our standardized features, resulting in the PCA score.
df_purchase_segm_pca=pca.transform(df_purchase_segm_std)

# %% [markdown]
# ### **K-means PCA**

# %% [markdown]
# Find the PCA scores for our K means pca model

# %%
purchase_segm_kmeans_pca=kmeans_pca.predict(df_purchase_segm_pca)

# %%
df_purchase_predictors=df_purchase.copy()

# %%
# Add a new column indicating the cluster the customer belongs to.
df_purchase_predictors['Segment']=purchase_segm_kmeans_pca

# %% [markdown]
# # **Descriptive Analysis by Segments**

# %% [markdown]
# ## **Data Analysis by Customer**

# %%
df_purchase_predictors.head()
# Out:
#           ID  Day  Incidence  Brand  Quantity  Last_Inc_Brand  \
# 0  200000001    1          0      0         0               0
# 1  200000001   11          0      0         0               0
# 2  200000001   12          0      0         0               0
# 3  200000001   16          0      0         0               0
# 4  200000001   18          0      0         0               0
#
#    Last_Inc_Quantity  Price_1  Price_2  Price_3  ...  Promotion_4  \
# 0                  0     1.59     1.87     2.01  ...            0
# 1                  0     1.51     1.89     1.99  ...            0
# 2                  0     1.51     1.89     1.99  ...            0
# 3                  0     1.52     1.89     1.98  ...            0
# 4                  0     1.52     1.89     1.99  ...            0
#
#    Promotion_5  Sex  Marital status  Age  Education  Income  Occupation  \
# 0            0    0               0   47          1  110866           1
# 1            0    0               0   47          1  110866           1
# 2            0    0               0   47          1  110866           1
# 3            0    0               0   47          1  110866           1
# 4            0    0               0   47          1  110866           1
#
#    Settlement size  Segment
# 0                0        2
# 1                0        2
# 2                0        2
# 3                0        2
# 4                0        2
#
# [5 rows x 25 columns]

# %% [markdown]
# Create dataframe with one record per individual, in order to summarize each customer's shopping behaviour.

# %% [markdown]
# Create a table with the number of visits per individual.

# %%
# Create a temporary variable containing the Nb of purchase occasions per individual (visits).
temp1=df_purchase_predictors[['ID','Incidence']].groupby(['ID'], as_index=False).count()
temp1=temp1.set_index('ID')

# Rename column in "Number of visits"
temp1=temp1.rename(columns={'Incidence':'N_Visits'})
temp1.head()
# Out:
#            N_Visits
# ID
# 200000001       101
# 200000002        87
# 200000003        97
# 200000004        85
# 200000005       111

# %% [markdown]
# Create a table with the number of purchases per individual.

# %%
# Nb of times a customer bought a product of interest.

temp2=df_purchase_predictors[['ID','Incidence']].groupby(['ID'],as_index=False).sum()
temp2=temp2.set_index('ID')
temp2=temp2.rename(columns={'Incidence':'N_Purchases'})

# %% [markdown]
# Join temp1 and temp2 tables containing the information regarding the number of times a customer visited the location and the number of times the customer bought something.

# %%
temp3=temp1.join(temp2)
temp3.head()
# Out:
#            N_Visits  N_Purchases
# ID
# 200000001       101            9
# 200000002        87           11
# 200000003        97           10
# 200000004        85           11
# 200000005       111           13

# %% [markdown]
# Average purchase frequency per individual: Nb a times a person has visited and bought from the store divided by the total number of visits by that individual.

# %%
temp3['Average_N_Purchases']=(temp3['N_Purchases']/temp3['N_Visits'])*100
temp3.head()
# Out:
#            N_Visits  N_Purchases  Average_N_Purchases
# ID
# 200000001       101            9             8.910891
# 200000002        87           11            12.643678
# 200000003        97           10            10.309278
# 200000004        85           11            12.941176
# 200000005       111           13            11.711712

# %% [markdown]
# Add segment to this new table.

# %%
temp4=df_purchase_predictors[['ID','Segment']].groupby(['ID'],as_index=False).mean()
temp4=temp4.set_index('ID')

# %%
# Join previous table with new table.

df_purchase_descr=temp3.join(temp4)

# %%
df_purchase_descr.head()
# Out:
#            N_Visits  N_Purchases  Average_N_Purchases  Segment
# ID
# 200000001       101            9             8.910891      2.0
# 200000002        87           11            12.643678      3.0
# 200000003        97           10            10.309278      2.0
# 200000004        85           11            12.941176      2.0
# 200000005       111           13            11.711712      1.0

# %% [markdown]
# ## **Segment Proportions**

# %% [markdown]
# **Proportion of purchases by segments.**

# %%
segm_prop=df_purchase_descr[['N_Purchases','Segment']].groupby(['Segment']).count()/df_purchase_descr.shape[0]
segm_prop=segm_prop.rename(columns={'N_Purchases':'Segment Proportions'})
segm_prop.head()
# Out:
#          Segment Proportions
# Segment
# 0.0                    0.206
# 1.0                    0.220
# 2.0                    0.378
# 3.0                    0.196

# %%
# Pie chart

plt.figure(figsize=(9,6))
plt.pie(segm_prop['Segment Proportions'],
        labels=['Standard','Career-Focused','Fewer opportunities','Well off'],
        autopct='%1.1f%%',
        colors=('b','g','r','orange'))
plt.title('Segment proportions')
# Out:
# Text(0.5, 1.0, 'Segment proportions')

# %% [markdown]
# ## **Purchase Occasion and Purchase Incidence**

# %% [markdown]
# Determine a quantitative measure to describe the purchase behaviour by segments.

# %% [markdown]
# Calculate mean and standard deviation by segments. The mean shows the average behaviour of each segment and the standard deviation shows how homogenous each segment is.

# %%
segments_mean=df_purchase_descr.groupby(['Segment']).mean()
segments_mean
# Out:
#            N_Visits  N_Purchases  Average_N_Purchases
# Segment
# 0.0      117.699029    24.902913            21.277313
# 1.0      123.454545    39.827273            28.310171
# 2.0      113.730159    22.756614            20.158818
# 3.0      117.295918    34.602041            28.447797

# %%
segments_std=df_purchase_descr.groupby(['Segment']).std()
segments_std
# Out:
#           N_Visits  N_Purchases  Average_N_Purchases
# Segment
# 0.0      19.039605    16.774464            12.660304
# 1.0      44.864656    53.744530            20.005613
# 2.0      16.410498    13.815040            12.033471
# 3.0      20.716152    25.900579            17.178714

# %% [markdown]
# **How often do people from different segments visit the store?**

# %%
plt.figure(figsize=(9,6))
plt.bar(x=(0,1,2,3), # 4 bars for x
        tick_label=('Standard','Career-Focused','Fewer opportunities','Well off'), # Labels
        height=segments_mean['N_Visits'], # Y axis
        yerr=segments_std['N_Visits'], # Y error -> standard deviation
        color=('b','g','r','orange'))
plt.xlabel('Segment')
plt.ylabel('Number of Store Visits')
plt.title('Average Number of Store Visits by Segment')
# Out:
# Text(0.5, 1.0, 'Average Number of Store Visits by Segment')

# %% [markdown]
# **How often a client buys a product.**

# %%
plt.figure(figsize=(9,6))
plt.bar(x=(0,1,2,3), # 4 bars for x
        tick_label=('Standard','Career-Focused','Fewer opportunities','Well off'), # Labels
        height=segments_mean['N_Purchases'], # Y axis
        yerr=segments_std['N_Purchases'], # Y error -> standard deviation
        color=('b','g','r','orange'))
plt.xlabel('Segment')
plt.ylabel('Purchase Incidences')
plt.title('Number of Purchase Incidences')
# Out:
# Text(0.5, 1.0, 'Number of Purchase Incidences')

# %% [markdown]
# **Average number of purchases by segment.**

# %%
plt.figure(figsize=(9,6))
plt.bar(x=(0,1,2,3), # 4 bars for x
        tick_label=('Standard','Career-Focused','Fewer opportunities','Well off'), # Labels
        height=segments_mean['Average_N_Purchases'], # Y axis
        yerr=segments_std['Average_N_Purchases'], # Y error -> standard deviation
        color=('b','g','r','orange'))
plt.xlabel('Segment')
plt.ylabel('Average nb of purchases')
plt.title('Average number of purchases by segment')
# Out:
# Text(0.5, 1.0, 'Average number of purchases by segment')

# %% [markdown]
# ## **Brand choice**

# %%
# df_purchase_predictors contains the segment info.
df_purchase_incidence=df_purchase_predictors[df_purchase_predictors['Incidence']==1]

# %% [markdown]
# Create dummy variables for the 5 brands, in order for each of them to have their own column.

# %%
# Set the prefix to 'Brand' and use _ as a separator
brand_dummies=pd.get_dummies(df_purchase_incidence['Brand'],prefix='Brand',prefix_sep='_')

# Set the 2 columns (Segment, ID) from the brand_dummies dataset to their counterparts from purchase_incidence.
brand_dummies['Segment'],brand_dummies['ID']=df_purchase_incidence['Segment'],df_purchase_incidence['ID']
brand_dummies
# Out:
#        Brand_1  Brand_2  Brand_3  Brand_4  Brand_5  Segment         ID
# 6            0        1        0        0        0        2  200000001
# 11           0        0        0        0        1        2  200000001
# 19           1        0        0        0        0        2  200000001
# 24           0        0        0        1        0        2  200000001
# 29           0        1        0        0        0        2  200000001
# ...        ...      ...      ...      ...      ...      ...        ...
# 58621        0        1        0        0        0        2  200000500
# 58648        1        0        0        0        0        2  200000500
# 58674        0        1        0        0        0        2  200000500
# 58687        0        1        0        0        0        2  200000500
# 58691        0        1        0        0        0        2  200000500
#
# [14638 rows x 7 columns]

# %%
# Declare a temporary variable storing the grouping by ID and taking the brand mean.
# If we set ID as an index, we'll be left with the average brand choice by customer.

temp=brand_dummies.groupby(['ID'],as_index=True).mean()

# %%
# Average brand choice by segment
mean_brand_choice=temp.groupby(['Segment'], as_index=True).mean()

# %%
# Brand choice by segments

sns.heatmap(mean_brand_choice,
            vmin=0,
            vmax=1,
            cmap='PuBu',
            annot=True)
plt.yticks([0,1,2,3],['Standard','Career-Focused','Fewer opportunities','Well off'], rotation=45, fontsize=9)
plt.title('Average Brand Choice by Segment')
plt.show()

# %% [markdown]
# ## **Revenue Analysis**

# %% [markdown]
# **Calculate revenues for Brand 1**

# %%
# Purchases for brand 1
temp=df_purchase_predictors[df_purchase_predictors['Brand']==1]

# Create a column representing Revenue for Brand 1
temp.loc[:,'Revenue Brand 1']=temp['Price_1']*temp['Quantity']
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %% [markdown]
# Create a new dataset with info related to revenue.

# %%
segments_brand_revenue=pd.DataFrame()
segments_brand_revenue[['Segment','Revenue Brand 1']]=temp[['Segment','Revenue Brand 1']].groupby(['Segment'],as_index=False).sum()
segments_brand_revenue
# Out:
#    Segment  Revenue Brand 1
# 0        0          2611.19
# 1        1           736.09
# 2        2          2258.90
# 3        3           699.47

# %% [markdown]
# Calculate the revenues for the next brands and append it to the new dataset.

# %% [markdown]
# Revenues for Brand 2

# %%
temp=df_purchase_predictors[df_purchase_predictors['Brand']==2]

temp.loc[:,'Revenue Brand 2']=temp['Price_2']*temp['Quantity']

segments_brand_revenue[['Segment','Revenue Brand 2']]=temp[['Segment','Revenue Brand 2']].groupby(['Segment'],as_index=False).sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %% [markdown]
# Revenues for Brand 3

# %%
temp=df_purchase_predictors[df_purchase_predictors['Brand']==3]

temp.loc[:,'Revenue Brand 3']=temp['Price_3']*temp['Quantity']

segments_brand_revenue[['Segment','Revenue Brand 3']]=temp[['Segment','Revenue Brand 3']].groupby(['Segment'],as_index=False).sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %% [markdown]
# Revenues for Brand 4

# %%
temp=df_purchase_predictors[df_purchase_predictors['Brand']==4]

temp.loc[:,'Revenue Brand 4']=temp['Price_4']*temp['Quantity']

segments_brand_revenue[['Segment','Revenue Brand 4']]=temp[['Segment','Revenue Brand 4']].groupby(['Segment'],as_index=False).sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %% [markdown]
# Revenues for Brand 5

# %%
temp=df_purchase_predictors[df_purchase_predictors['Brand']==5]

temp.loc[:,'Revenue Brand 5']=temp['Price_5']*temp['Quantity']

segments_brand_revenue[['Segment','Revenue Brand 5']]=temp[['Segment','Revenue Brand 5']].groupby(['Segment'],as_index=False).sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %% [markdown]
# Calculate the entire revenue by segment.

# %%
# Create a new column
segments_brand_revenue['Total Revenue']=(segments_brand_revenue['Revenue Brand 1']+
                                         segments_brand_revenue['Revenue Brand 2']+
                                         segments_brand_revenue['Revenue Brand 3']+
                                         segments_brand_revenue['Revenue Brand 4']+
                                         segments_brand_revenue['Revenue Brand 5']
                                         )
segments_brand_revenue
# Out:
#    Segment  Revenue Brand 1  Revenue Brand 2  Revenue Brand 3  \
# 0        0          2611.19          4768.52          3909.17
# 1        1           736.09          1746.42           664.75
# 2        2          2258.90         13955.14           716.25
# 3        3           699.47          1298.23           731.35
#
#    Revenue Brand 4  Revenue Brand 5  Total Revenue
# 0           861.38          2439.75       14590.01
# 1          2363.84         19441.06       24952.16
# 2          1629.31          2230.50       20790.10
# 3         14185.57          5509.69       22424.31

# %% [markdown]
# Add the proportion of each segment from the Segment proportion dataframe.

# %%
# Append Segment proportion info from the segment proportion dataframe.
segments_brand_revenue['Segment Proportions']=segm_prop['Segment Proportions']

# Map the segments with descriptive labels.
segments_brand_revenue['Segment']=segments_brand_revenue['Segment'].map({0:'Standard',
                                                                         1:'Career-Focused',
                                                                         2:'Fewer opportunities',
                                                                         3:'Well off'})

# Set the segment as the index                                                                         
segments_brand_revenue=segments_brand_revenue.set_index(['Segment'])
segments_brand_revenue
# Out:
#                      Revenue Brand 1  Revenue Brand 2  Revenue Brand 3  \
# Segment
# Standard                     2611.19          4768.52          3909.17
# Career-Focused                736.09          1746.42           664.75
# Fewer opportunities          2258.90         13955.14           716.25
# Well off                      699.47          1298.23           731.35
#
#                      Revenue Brand 4  Revenue Brand 5  Total Revenue  \
# Segment
# Standard                      861.38          2439.75       14590.01
# Career-Focused               2363.84         19441.06       24952.16
# Fewer opportunities          1629.31          2230.50       20790.10
# Well off                    14185.57          5509.69       22424.31
#
#                      Segment Proportions
# Segment
# Standard                           0.206
# Career-Focused                     0.220
# Fewer opportunities                0.378
# Well off                           0.196

# %% [markdown]
# # **Modeling Purchase Incidence**
#
# **Will a customer buy a product or not?**

# %% [markdown]
# The necessary scaling, pca, kmeans, standardization, segmentation steps are already done above.

# %%
# Create a clone dataset of the df_purchase_predictors
df_pa=df_purchase_predictors

# %% [markdown]
# ## **Purchase Probability Model - Logistic Regression**

# %%
Y=df_pa['Incidence']

# %%
# Create a variable representing the price, irrespective of the brand.
X=pd.DataFrame()
X['Mean_Price']=(df_pa['Price_1']+
                 df_pa['Price_2']+
                 df_pa['Price_3']+
                 df_pa['Price_4']+
                 df_pa['Price_5']
                 )/5

# %%
model_purchase=LogisticRegression(solver='sag')
model_purchase.fit(X,Y)
# Out:
# LogisticRegression(solver='sag')

# %% [markdown]
# **This model quantifies the exact relationship between price and purchase probability.**

# %%
model_purchase.coef_
# Out:
# array([[-2.3480731]])

# %% [markdown]
# ## **Price Elasticity of Purchase Probability**

# %% [markdown]
# The data will be representative of the average customer.

# %% [markdown]
# We'll analyze the  prices variables.

# %%
df_pa[['Price_1','Price_2','Price_3','Price_4','Price_5']].describe()
# Out:
#             Price_1       Price_2       Price_3       Price_4       Price_5
# count  58693.000000  58693.000000  58693.000000  58693.000000  58693.000000
# mean       1.392074      1.780999      2.006789      2.159945      2.654798
# std        0.091139      0.170868      0.046867      0.089825      0.098272
# min        1.100000      1.260000      1.870000      1.760000      2.110000
# 25%        1.340000      1.580000      1.970000      2.120000      2.630000
# 50%        1.390000      1.880000      2.010000      2.170000      2.670000
# 75%        1.470000      1.890000      2.060000      2.240000      2.700000
# max        1.590000      1.900000      2.140000      2.260000      2.800000

# %% [markdown]
# We'll analyze a range of prices, let's set the range between 0.5 (lower than min) and 3.5 (higher than max).

# %%
price_range=np.arange(0.5,3.5,0.01)
price_range
# Out:
# array([0.5 , 0.51, 0.52, 0.53, 0.54, 0.55, 0.56, 0.57, 0.58, 0.59, 0.6 ,
#        0.61, 0.62, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.7 , 0.71,
#        0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.8 , 0.81, 0.82,
#        0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89, 0.9 , 0.91, 0.92, 0.93,
#        0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1.  , 1.01, 1.02, 1.03, 1.04,
#        1.05, 1.06, 1.07, 1.08, 1.09, 1.1 , 1.11, 1.12, 1.13, 1.14, 1.15,
#        1.16, 1.17, 1.18, 1.19, 1.2 , 1.21, 1.22, 1.23, 1.24, 1.25, 1.26,
#        1.27, 1.28, 1.29, 1.3 , 1.31, 1.32, 1.33, 1.34, 1.35, 1.36, 1.37,
#        1.38, 1.39, 1.4 , 1.41, 1.42, 1.43, 1.44, 1.45, 1.46, 1.47, 1.48,
#        1.49, 1.5 , 1.51, 1.52, 1.53, 1.54, 1.55, 1.56, 1.57, 1.58, 1.59,
#        1.6 , 1.61, 1.62, 1.63, 1.64, 1.65, 1.66, 1.67, 1.68, 1.69, 1.7 ,
#        1.71, 1.72, 1.73, 1.74, 1.75, 1.76, 1.77, 1.78, 1.79, 1.8 , 1.81,
#        1.82, 1.83, 1.84, 1.85, 1.86, 1.87, 1.88, 1.89, 1.9 , 1.91, 1.92,
#        1.93, 1.94, 1.95, 1.96, 1.97, 1.98, 1.99, 2.  , 2.01, 2.02, 2.03,
#        2.04, 2.05, 2.06, 2.07, 2.08, 2.09, 2.1 , 2.11, 2.12, 2.13, 2.14,
#        2.15, 2.16, 2.17, 2.18, 2.19, 2.2 , 2.21, 2.22, 2.23, 2.24, 2.25,
#        2.26, 2.27, 2.28, 2.29, 2.3 , 2.31, 2.32, 2.33, 2.34, 2.35, 2.36,
#        2.37, 2.38, 2.39, 2.4 , 2.41, 2.42, 2.43, 2.44, 2.45, 2.46, 2.47,
#        2.48, 2.49, 2.5 , 2.51, 2.52, 2.53, 2.54, 2.55, 2.56, 2.57, 2.58,
#        2.59, 2.6 , 2.61, 2.62, 2.63, 2.64, 2.65, 2.66, 2.67, 2.68, 2.69,
#        2.7 , 2.71, 2.72, 2.73, 2.74, 2.75, 2.76, 2.77, 2.78, 2.79, 2.8 ,
#        2.81, 2.82, 2.83, 2.84, 2.85, 2.86, 2.87, 2.88, 2.89, 2.9 , 2.91,
#        2.92, 2.93, 2.94, 2.95, 2.96, 2.97, 2.98, 2.99, 3.  , 3.01, 3.02,
#        3.03, 3.04, 3.05, 3.06, 3.07, 3.08, 3.09, 3.1 , 3.11, 3.12, 3.13,
#        3.14, 3.15, 3.16, 3.17, 3.18, 3.19, 3.2 , 3.21, 3.22, 3.23, 3.24,
#        3.25, 3.26, 3.27, 3.28, 3.29, 3.3 , 3.31, 3.32, 3.33, 3.34, 3.35,
#        3.36, 3.37, 3.38, 3.39, 3.4 , 3.41, 3.42, 3.43, 3.44, 3.45, 3.46,
#        3.47, 3.48, 3.49])

# %%
# Assign the price range to a new dataset.
df_price_range=pd.DataFrame(price_range)

# %% [markdown]
# Predict the probability of purchase for each price

# %%
Y_pred=model_purchase.predict_proba(df_price_range)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
# The array has a row for each price value. The first value represents the probability of no purchase, and the second, the probability of purchase.
Y_pred
# Out:
# array([[0.08211556, 0.91788444],
#        [0.08390282, 0.91609718],
#        [0.08572534, 0.91427466],
#        [0.08758367, 0.91241633],
#        [0.08947834, 0.91052166],
#        [0.09140989, 0.90859011],
#        [0.09337887, 0.90662113],
#        [0.0953858 , 0.9046142 ],
#        [0.09743123, 0.90256877],
#        [0.09951569, 0.90048431],
#        [0.10163973, 0.89836027],
#        [0.10380388, 0.89619612],
#        [0.10600867, 0.89399133],
#        [0.10825463, 0.89174537],
#        [0.11054229, 0.88945771],
#        [0.11287218, 0.88712782],
#        [0.11524481, 0.88475519],
#        [0.11766071, 0.88233929],
#        [0.12012037, 0.87987963],
#        [0.1226243 , 0.8773757 ],
#        [0.125173  , 0.874827  ],
#        [0.12776696, 0.87223304],
#        [0.13040667, 0.86959333],
#        [0.13309258, 0.86690742],
#        [0.13582518, 0.86417482],
#        [0.13860492, 0.86139508],
#        [0.14143223, 0.85856777],
#        [0.14430755, 0.85569245],
#        [0.1472313 , 0.8527687 ],
#        [0.15020389, 0.84979611],
#        [0.15322572, 0.84677428],
#        [0.15629715, 0.84370285],
#        [0.15941857, 0.84058143],
#        [0.1625903 , 0.8374097 ],
#        [0.1658127 , 0.8341873 ],
#        [0.16908606, 0.83091394],
#        [0.17241069, 0.82758931],
#        [0.17578686, 0.82421314],
#        [0.17921482, 0.82078518],
#        [0.18269482, 0.81730518],
#        [0.18622705, 0.81377295],
#        [0.18981172, 0.81018828],
#        [0.19344899, 0.80655101],
#        [0.197139  , 0.802861  ],
#        [0.20088186, 0.79911814],
#        [0.20467767, 0.79532233],
#        [0.20852648, 0.79147352],
#        [0.21242834, 0.78757166],
#        [0.21638325, 0.78361675],
#        [0.22039119, 0.77960881],
#        [0.2244521 , 0.7755479 ],
#        [0.2285659 , 0.7714341 ],
#        [0.23273246, 0.76726754],
#        [0.23695166, 0.76304834],
#        [0.24122329, 0.75877671],
#        [0.24554715, 0.75445285],
#        [0.24992299, 0.75007701],
#        [0.25435052, 0.74564948],
#        [0.25882942, 0.74117058],
#        [0.26335933, 0.73664067],
#        [0.26793986, 0.73206014],
#        [0.27257058, 0.72742942],
#        [0.27725102, 0.72274898],
#        [0.28198068, 0.71801932],
#        [0.28675901, 0.71324099],
#        [0.29158542, 0.70841458],
#        [0.29645931, 0.70354069],
#        [0.30138   , 0.69862   ],
#        [0.30634681, 0.69365319],
#        [0.31135899, 0.68864101],
#        [0.31641577, 0.68358423],
#        [0.32151633, 0.67848367],
#        [0.32665982, 0.67334018],
#        [0.33184535, 0.66815465],
#        [0.33707199, 0.66292801],
#        [0.34233877, 0.65766123],
#        [0.34764469, 0.65235531],
#        [0.3529887 , 0.6470113 ],
#        [0.35836974, 0.64163026],
#        [0.36378669, 0.63621331],
#        [0.97332842, 0.02667158],
#        [0.97393126, 0.02606874],
#        [0.97452083, 0.02547917],
#        [0.9750974 , 0.0249026 ],
#        [0.97566126, 0.02433874],
#        [0.97621266, 0.02378734],
#        [0.97675186, 0.02324814],
#        [0.97727913, 0.02272087],
#        [0.97779471, 0.02220529],
#        [0.97829885, 0.02170115],
#        [0.97879179, 0.02120821],
#        [0.97927377, 0.02072623],
#        [0.97974502, 0.02025498],
#        [0.98020578, 0.01979422],
#        [0.98065626, 0.01934374],
#        [0.98109669, 0.01890331],
#        [0.98152728, 0.01847272],
#        [0.98194824, 0.01805176],
#        [0.98235978, 0.01764022],
#        [0.98276211, 0.01723789],
#        [0.98315541, 0.01684459],
#        [0.98353989, 0.01646011],
#        [0.98391574, 0.01608426],
#        [0.98428315, 0.01571685],
#        [0.98464229, 0.01535771],
#        [0.98499335, 0.01500665],
#        [0.98533651, 0.01466349],
#        [0.98567193, 0.01432807],
#        [0.98599979, 0.01400021],
#        [0.98632025, 0.01367975],
#        [0.98663347, 0.01336653],
#        [0.98693962, 0.01306038],
#        [0.98723885, 0.01276115],
#        [0.98753131, 0.01246869],
#        [0.98781715, 0.01218285],
#        [0.98809651, 0.01190349],
#        [0.98836954, 0.01163046],
#        [0.98863639, 0.01136361],
#        [0.98889718, 0.01110282],
#        [0.98915205, 0.01084795],
#        [0.98940113, 0.01059887],
#        [0.98964455, 0.01035545],
#        [0.98988244, 0.01011756],
#        [0.99011492, 0.00988508]])

# %% [markdown]
# Store the probability of purchase (second value from above probability array)

# %%
# Purchase probability
purchase_pr=Y_pred[:][:,1]

# %% [markdown]
# Purchase probability elasticity = (delta purchase probability /purchase probability)/(delta price/price)
#
# =(delta purchase probability/delta price) * (Price/Purchase probability)
#
# E= beta * price * (1-purchase probability)
#
# beta-> coefficient from the model

# %%
# Create a price elasticity variable
# =price coef from the model (array with shape 1, number of features) * price_range * (1-purchase_pr)

pe=model_purchase.coef_[:,0] * price_range * (1-purchase_pr)

# %%
df_price_elasticities=pd.DataFrame(price_range)

# %%
df_price_elasticities=df_price_elasticities.rename(columns={0: 'Price_Point'})
df_price_elasticities['Mean_PE']=pe
df_price_elasticities
# Out:
#      Price_Point   Mean_PE
# 0           0.50 -0.096407
# 1           0.51 -0.100475
# 2           0.52 -0.104670
# 3           0.53 -0.108996
# 4           0.54 -0.113455
# ..           ...       ...
# 295         3.45 -8.012975
# 296         3.46 -8.038224
# 297         3.47 -8.063439
# 298         3.48 -8.088621
# 299         3.49 -8.113769
#
# [300 rows x 2 columns]

# %%
pd.options.display.max_rows=None
df_price_elasticities
# Out:
#      Price_Point   Mean_PE
# 0           0.50 -0.096407
# 1           0.51 -0.100475
# 2           0.52 -0.104670
# 3           0.53 -0.108996
# 4           0.54 -0.113455
# 5           0.55 -0.118050
# 6           0.56 -0.122786
# 7           0.57 -0.127665
# 8           0.58 -0.132690
# 9           0.59 -0.137865
# 10          0.60 -0.143195
# 11          0.61 -0.148681
# 12          0.62 -0.154328
# 13          0.63 -0.160140
# 14          0.64 -0.166119
# 15          0.65 -0.172271
# 16          0.66 -0.178598
# 17          0.67 -0.185105
# 18          0.68 -0.191795
# 19          0.69 -0.198672
# 20          0.70 -0.205741
# 21          0.71 -0.213004
# 22          0.72 -0.220467
# 23          0.73 -0.228133
# 24          0.74 -0.236006
# 25          0.75 -0.244091
# 26          0.76 -0.252391
# 27          0.77 -0.260910
# 28          0.78 -0.269654
# 29          0.79 -0.278625
# 30          0.80 -0.287828
# 31          0.81 -0.297268
# 32          0.82 -0.306948
# 33          0.83 -0.316872
# 34          0.84 -0.327046
# 35          0.85 -0.337472
# 36          0.86 -0.348156
# 37          0.87 -0.359102
# 38          0.88 -0.370312
# 39          0.89 -0.381793
# 40          0.90 -0.393547
# 41          0.91 -0.405580
# 42          0.92 -0.417894
# 43          0.93 -0.430494
# 44          0.94 -0.443384
# 45          0.95 -0.456568
# 46          0.96 -0.470050
# 47          0.97 -0.483833
# 48          0.98 -0.497922
# 49          0.99 -0.512320
# 50          1.00 -0.527030
# 51          1.01 -0.542056
# 52          1.02 -0.557402
# 53          1.03 -0.573071
# 54          1.04 -0.589066
# 55          1.05 -0.605391
# 56          1.06 -0.622048
# 57          1.07 -0.639040
# 58          1.08 -0.656370
# 59          1.09 -0.674042
# 60          1.10 -0.692057
# 61          1.11 -0.710417
# 62          1.12 -0.729126
# 63          1.13 -0.748186
# 64          1.14 -0.767597
# 65          1.15 -0.787363
# 66          1.16 -0.807485
# 67          1.17 -0.827965
# 68          1.18 -0.848803
# 69          1.19 -0.870001
# 70          1.20 -0.891561
# 71          1.21 -0.913482
# 72          1.22 -0.935766
# 73          1.23 -0.958412
# 74          1.24 -0.981422
# 75          1.25 -1.004796
# 76          1.26 -1.028532
# 77          1.27 -1.052631
# 78          1.28 -1.077092
# 79          1.29 -1.101915
# 80          1.30 -1.127098
# 81          1.31 -1.152641
# 82          1.32 -1.178541
# 83          1.33 -1.204798
# 84          1.34 -1.231410
# 85          1.35 -1.258373
# 86          1.36 -1.285687
# 87          1.37 -1.313349
# 88          1.38 -1.341355
# 89          1.39 -1.369704
# 90          1.40 -1.398391
# 91          1.41 -1.427414
# 92          1.42 -1.456770
# 93          1.43 -1.486453
# 94          1.44 -1.516461
# 95          1.45 -1.546789
# 96          1.46 -1.577433
# 97          1.47 -1.608389
# 98          1.48 -1.639651
# 99          1.49 -1.671214
# 100         1.50 -1.703075
# 101         1.51 -1.735226
# 102         1.52 -1.767664
# 103         1.53 -1.800382
# 104         1.54 -1.833374
# 105         1.55 -1.866635
# 106         1.56 -1.900158
# 107         1.57 -1.933938
# 108         1.58 -1.967968
# 109         1.59 -2.002242
# 110         1.60 -2.036752
# 111         1.61 -2.071493
# 112         1.62 -2.106458
# 113         1.63 -2.141639
# 114         1.64 -2.177030
# 115         1.65 -2.212624
# 116         1.66 -2.248414
# 117         1.67 -2.284392
# 118         1.68 -2.320551
# 119         1.69 -2.356885
# 120         1.70 -2.393385
# 121         1.71 -2.430045
# 122         1.72 -2.466857
# 123         1.73 -2.503814
# 124         1.74 -2.540908
# 125         1.75 -2.578133
# 126         1.76 -2.615480
# 127         1.77 -2.652943
# 128         1.78 -2.690514
# 129         1.79 -2.728186
# 239         2.89 -6.519632
# 240         2.90 -6.548154
# 241         2.91 -6.576590
# 242         2.92 -6.604940
# 243         2.93 -6.633204
# 244         2.94 -6.661386
# 245         2.95 -6.689484
# 246         2.96 -6.717502
# 247         2.97 -6.745439
# 248         2.98 -6.773298
# 249         2.99 -6.801079
# 250         3.00 -6.828783
# 251         3.01 -6.856412
# 252         3.02 -6.883967
# 253         3.03 -6.911449
# 254         3.04 -6.938858
# 255         3.05 -6.966197
# 256         3.06 -6.993466
# 257         3.07 -7.020666
# 258         3.08 -7.047798
# 259         3.09 -7.074864
# 260         3.10 -7.101864
# 261         3.11 -7.128800
# 262         3.12 -7.155672
# 263         3.13 -7.182482
# 264         3.14 -7.209231
# 265         3.15 -7.235919
# 266         3.16 -7.262548
# 267         3.17 -7.289118
# 268         3.18 -7.315631
# 269         3.19 -7.342087
# 270         3.20 -7.368488
# 271         3.21 -7.394834
# 272         3.22 -7.421127
# 273         3.23 -7.447367
# 274         3.24 -7.473554
# 275         3.25 -7.499691
# 276         3.26 -7.525778
# 277         3.27 -7.551815
# 278         3.28 -7.577804
# 279         3.29 -7.603745
# 280         3.30 -7.629640
# 281         3.31 -7.655488
# 282         3.32 -7.681292
# 283         3.33 -7.707051
# 284         3.34 -7.732767
# 285         3.35 -7.758439
# 286         3.36 -7.784070
# 287         3.37 -7.809659
# 288         3.38 -7.835208
# 289         3.39 -7.860717
# 290         3.40 -7.886187
# 291         3.41 -7.911619
# 292         3.42 -7.937013
# 293         3.43 -7.962369
# 294         3.44 -7.987690
# 295         3.45 -8.012975
# 296         3.46 -8.038224
# 297         3.47 -8.063439
# 298         3.48 -8.088621
# 299         3.49 -8.113769

# %%
plt.figure(figsize=(9,6))
plt.plot(price_range,pe,color='grey')
plt.xlabel('Price')
plt.ylabel('Elasticity')
plt.title('Price elasticity of purchase probability')
# Out:
# Text(0.5, 1.0, 'Price elasticity of purchase probability')

# %% [markdown]
# For inelastic (less than 1) values we increase price.
#
# For elastic values, we decrease price.

# %% [markdown]
# ## **Purchase Probability by Segments**

# %% [markdown]
# **Segment 0**

# %%
df_pa_segment_0=df_pa[df_pa['Segment']==0]
Y0=df_pa_segment_0['Incidence']
X0=pd.DataFrame()
X0['Mean_Price']=(df_pa_segment_0['Price_1']+
                  df_pa_segment_0['Price_2']+
                  df_pa_segment_0['Price_3']+
                  df_pa_segment_0['Price_4']+
                  df_pa_segment_0['Price_5']
                  )/5

model_incidence_segment_0=LogisticRegression(solver='sag')
model_incidence_segment_0.fit(X0,Y0)

model_incidence_segment_0.coef_

Y_segment_0=model_incidence_segment_0.predict_proba(df_price_range)
purchase_pr_segment_0=Y_segment_0[:][:,1]
pe_segment_0=model_incidence_segment_0.coef_[:,0]*price_range*(1-purchase_pr_segment_0)

df_price_elasticities['PE_Segment_0']=pe_segment_0
df_price_elasticities
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# 261     -4.494422     -4.466779
# 262     -4.512075     -4.484349
# 263     -4.529706     -4.501896
# 264     -4.547313     -4.519419
# 265     -4.564897     -4.536920
# 266     -4.582458     -4.554398
# 267     -4.599996     -4.571854
# 268     -4.617511     -4.589287
# 269     -4.635004     -4.606697
# 270     -4.652474     -4.624085
# 271     -4.669922     -4.641451
# 272     -4.687347     -4.658795
# 273     -4.704751     -4.676117
# 274     -4.722132     -4.693418
# 275     -4.739492     -4.710696
# 276     -4.756830     -4.727954
# 277     -4.774146     -4.745190
# 278     -4.791441     -4.762404
# 279     -4.808715     -4.779598
# 280     -4.825968     -4.796770
# 281     -4.843199     -4.813922
# 282     -4.860410     -4.831053
# 283     -4.877600     -4.848164
# 284     -4.894769     -4.865254
# 285     -4.911918     -4.882324
# 286     -4.929047     -4.899373
# 287     -4.946156     -4.916403
# 288     -4.963244     -4.933413
# 289     -4.980313     -4.950403
# 290     -4.997362     -4.967374
# 291     -5.014392     -4.984325
# 292     -5.031402     -5.001257
# 293     -5.048393     -5.018170
# 294     -5.065365     -5.035064
# 295     -5.082318     -5.051939
# 296     -5.099252     -5.068796
# 297     -5.116167     -5.085634
# 298     -5.133064     -5.102453
# 299     -5.149943     -5.119254

# %%
plt.figure(figsize=(9,6))
plt.plot(price_range,pe,color='grey')
plt.plot(price_range,pe_segment_0,color='orange')
plt.plot(price_range,pe_segment_1,color='green')
plt.plot(price_range,pe_segment_2,color='r')
plt.plot(price_range,pe_segment_3,color='b')

plt.xlabel('Price')
plt.ylabel('Elasticity')
plt.title('Price elasticity of purchase probability')
# Out:
# Text(0.5, 1.0, 'Price elasticity of purchase probability')

# %% [markdown]
# **Segment 1: Career - Focused**

# %%
df_pa_segment_1=df_pa[df_pa['Segment']==1]

# %%
Y1=df_pa_segment_1['Incidence']

# %%
X1=pd.DataFrame()
X1['Mean_Price']=(df_pa_segment_1['Price_1']+
                  df_pa_segment_1['Price_2']+
                  df_pa_segment_1['Price_3']+
                  df_pa_segment_1['Price_4']+
                  df_pa_segment_1['Price_5']
                  )/5

# %%
model_incidence_segment_1=LogisticRegression(solver='sag')
model_incidence_segment_1.fit(X1,Y1)
# Out:
# LogisticRegression(solver='sag')

# %%
model_incidence_segment_1.coef_
# Out:
# array([[-1.71484664]])

# %%
Y_segment_1=model_incidence_segment_1.predict_proba(df_price_range)
purchase_pr_segment_1=Y_segment_1[:][:,1]
pe_segment_1=model_incidence_segment_1.coef_[:,0]*price_range*(1-purchase_pr_segment_1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
df_price_elasticities['PE_Segment_1']=pe_segment_1
df_price_elasticities
# Out:
#      Price_Point   Mean_PE  PE_Segment_1
# 0           0.50 -0.096407     -0.119409
# 1           0.51 -0.100475     -0.123606
# 2           0.52 -0.104670     -0.127897
# 3           0.53 -0.108996     -0.132283
# 4           0.54 -0.113455     -0.136766
# 5           0.55 -0.118050     -0.141347
# 6           0.56 -0.122786     -0.146027
# 7           0.57 -0.127665     -0.150809
# 8           0.58 -0.132690     -0.155694
# 9           0.59 -0.137865     -0.160682
# 10          0.60 -0.143195     -0.165777
# 11          0.61 -0.148681     -0.170978
# 12          0.62 -0.154328     -0.176288
# 13          0.63 -0.160140     -0.181709
# 14          0.64 -0.166119     -0.187241
# 15          0.65 -0.172271     -0.192887
# 16          0.66 -0.178598     -0.198648
# 17          0.67 -0.185105     -0.204524
# 18          0.68 -0.191795     -0.210519
# 19          0.69 -0.198672     -0.216633
# 20          0.70 -0.205741     -0.222868
# 21          0.71 -0.213004     -0.229226
# 22          0.72 -0.220467     -0.235708
# 23          0.73 -0.228133     -0.242315
# 24          0.74 -0.236006     -0.249049
# 25          0.75 -0.244091     -0.255912
# 26          0.76 -0.252391     -0.262904
# 27          0.77 -0.260910     -0.270028
# 28          0.78 -0.269654     -0.277286
# 29          0.79 -0.278625     -0.284677
# 30          0.80 -0.287828     -0.292205
# 31          0.81 -0.297268     -0.299870
# 32          0.82 -0.306948     -0.307674
# 33          0.83 -0.316872     -0.315618
# 34          0.84 -0.327046     -0.323704
# 35          0.85 -0.337472     -0.331933
# 36          0.86 -0.348156     -0.340307
# 37          0.87 -0.359102     -0.348826
# 38          0.88 -0.370312     -0.357493
# 39          0.89 -0.381793     -0.366308
# 40          0.90 -0.393547     -0.375273
# 41          0.91 -0.405580     -0.384389
# 42          0.92 -0.417894     -0.393657
# 43          0.93 -0.430494     -0.403079
# 44          0.94 -0.443384     -0.412656
# 45          0.95 -0.456568     -0.422389
# 46          0.96 -0.470050     -0.432280
# 47          0.97 -0.483833     -0.442328
# 48          0.98 -0.497922     -0.452536
# 49          0.99 -0.512320     -0.462905
# 50          1.00 -0.527030     -0.473436
# 51          1.01 -0.542056     -0.484129
# 52          1.02 -0.557402     -0.494986
# 53          1.03 -0.573071     -0.506007
# 54          1.04 -0.589066     -0.517194
# 55          1.05 -0.605391     -0.528548
# 56          1.06 -0.622048     -0.540068
# 57          1.07 -0.639040     -0.551757
# 58          1.08 -0.656370     -0.563615
# 59          1.09 -0.674042     -0.575643
# 60          1.10 -0.692057     -0.587840
# 61          1.11 -0.710417     -0.600209
# 62          1.12 -0.729126     -0.612749
# 63          1.13 -0.748186     -0.625462
# 64          1.14 -0.767597     -0.638347
# 65          1.15 -0.787363     -0.651406
# 66          1.16 -0.807485     -0.664638
# 67          1.17 -0.827965     -0.678044
# 68          1.18 -0.848803     -0.691624
# 69          1.19 -0.870001     -0.705379
# 70          1.20 -0.891561     -0.719309
# 71          1.21 -0.913482     -0.733415
# 72          1.22 -0.935766     -0.747695
# 73          1.23 -0.958412     -0.762151
# 74          1.24 -0.981422     -0.776782
# 75          1.25 -1.004796     -0.791589
# 76          1.26 -1.028532     -0.806571
# 77          1.27 -1.052631     -0.821728
# 78          1.28 -1.077092     -0.837060
# 79          1.29 -1.101915     -0.852568
# 80          1.30 -1.127098     -0.868249
# 81          1.31 -1.152641     -0.884106
# 82          1.32 -1.178541     -0.900136
# 83          1.33 -1.204798     -0.916339
# 84          1.34 -1.231410     -0.932716
# 85          1.35 -1.258373     -0.949265
# 86          1.36 -1.285687     -0.965986
# 87          1.37 -1.313349     -0.982878
# 88          1.38 -1.341355     -0.999941
# 89          1.39 -1.369704     -1.017174
# 90          1.40 -1.398391     -1.034576
# 243         2.93 -6.633204     -4.585305
# 244         2.94 -6.661386     -4.607802
# 245         2.95 -6.689484     -4.630250
# 246         2.96 -6.717502     -4.652647
# 247         2.97 -6.745439     -4.674994
# 248         2.98 -6.773298     -4.697291
# 249         2.99 -6.801079     -4.719538
# 250         3.00 -6.828783     -4.741735
# 251         3.01 -6.856412     -4.763883
# 252         3.02 -6.883967     -4.785981
# 253         3.03 -6.911449     -4.808029
# 254         3.04 -6.938858     -4.830029
# 255         3.05 -6.966197     -4.851980
# 256         3.06 -6.993466     -4.873882
# 257         3.07 -7.020666     -4.895735
# 258         3.08 -7.047798     -4.917540
# 259         3.09 -7.074864     -4.939296
# 260         3.10 -7.101864     -4.961005
# 261         3.11 -7.128800     -4.982666
# 262         3.12 -7.155672     -5.004279
# 263         3.13 -7.182482     -5.025845
# 264         3.14 -7.209231     -5.047364
# 265         3.15 -7.235919     -5.068836
# 266         3.16 -7.262548     -5.090262
# 267         3.17 -7.289118     -5.111641
# 268         3.18 -7.315631     -5.132975
# 269         3.19 -7.342087     -5.154263
# 270         3.20 -7.368488     -5.175505
# 271         3.21 -7.394834     -5.196702
# 272         3.22 -7.421127     -5.217854
# 273         3.23 -7.447367     -5.238962
# 274         3.24 -7.473554     -5.260025
# 275         3.25 -7.499691     -5.281045
# 276         3.26 -7.525778     -5.302021
# 277         3.27 -7.551815     -5.322953
# 278         3.28 -7.577804     -5.343842
# 279         3.29 -7.603745     -5.364689
# 280         3.30 -7.629640     -5.385493
# 281         3.31 -7.655488     -5.406255
# 282         3.32 -7.681292     -5.426976
# 283         3.33 -7.707051     -5.447655
# 284         3.34 -7.732767     -5.468292
# 285         3.35 -7.758439     -5.488889
# 286         3.36 -7.784070     -5.509446
# 287         3.37 -7.809659     -5.529962
# 288         3.38 -7.835208     -5.550439
# 289         3.39 -7.860717     -5.570876
# 290         3.40 -7.886187     -5.591274
# 291         3.41 -7.911619     -5.611634
# 292         3.42 -7.937013     -5.631954
# 293         3.43 -7.962369     -5.652237
# 294         3.44 -7.987690     -5.672482
# 295         3.45 -8.012975     -5.692690
# 296         3.46 -8.038224     -5.712860
# 297         3.47 -8.063439     -5.732994
# 298         3.48 -8.088621     -5.753091
# 299         3.49 -8.113769     -5.773152

# %%
plt.figure(figsize=(9,6))
plt.plot(price_range,pe,color='grey')
plt.plot(price_range,pe_segment_1,color='green')
plt.xlabel('Price')
plt.ylabel('Elasticity')
plt.title('Price elasticity of purchase probability')
# Out:
# Text(0.5, 1.0, 'Price elasticity of purchase probability')

# %% [markdown]
# **Segment 2 - Fewer opportunities**

# %%
df_pa_segment_2=df_pa[df_pa['Segment']==2]
Y2=df_pa_segment_2['Incidence']
X2=pd.DataFrame()
X2['Mean_Price']=(df_pa_segment_2['Price_1']+
                  df_pa_segment_2['Price_2']+
                  df_pa_segment_2['Price_3']+
                  df_pa_segment_2['Price_4']+
                  df_pa_segment_2['Price_5']
                  )/5

model_incidence_segment_2=LogisticRegression(solver='sag')
model_incidence_segment_2.fit(X2,Y2)

model_incidence_segment_2.coef_

Y_segment_2=model_incidence_segment_2.predict_proba(df_price_range)
purchase_pr_segment_2=Y_segment_2[:][:,1]
pe_segment_2=model_incidence_segment_2.coef_[:,0]*price_range*(1-purchase_pr_segment_2)

df_price_elasticities['PE_Segment_2']=pe_segment_2
df_price_elasticities
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# 287         3.37 -7.809659     -5.529962    -12.254909
# 288         3.38 -7.835208     -5.550439    -12.292016
# 289         3.39 -7.860717     -5.570876    -12.329101
# 290         3.40 -7.886187     -5.591274    -12.366165
# 291         3.41 -7.911619     -5.611634    -12.403208
# 292         3.42 -7.937013     -5.631954    -12.440230
# 293         3.43 -7.962369     -5.652237    -12.477234
# 294         3.44 -7.987690     -5.672482    -12.514218
# 295         3.45 -8.012975     -5.692690    -12.551184
# 296         3.46 -8.038224     -5.712860    -12.588133
# 297         3.47 -8.063439     -5.732994    -12.625065
# 298         3.48 -8.088621     -5.753091    -12.661980
# 299         3.49 -8.113769     -5.773152    -12.698879

# %%
plt.figure(figsize=(9,6))
plt.plot(price_range,pe,color='grey')
plt.plot(price_range,pe_segment_1,color='green')
plt.plot(price_range,pe_segment_2,color='r')
plt.xlabel('Price')
plt.ylabel('Elasticity')
plt.title('Price elasticity of purchase probability')
# Out:
# Text(0.5, 1.0, 'Price elasticity of purchase probability')

# %% [markdown]
# **Segment 3**

# %%
df_pa_segment_3=df_pa[df_pa['Segment']==3]
Y3=df_pa_segment_3['Incidence']
X3=pd.DataFrame()
X3['Mean_Price']=(df_pa_segment_3['Price_1']+
                  df_pa_segment_3['Price_2']+
                  df_pa_segment_3['Price_3']+
                  df_pa_segment_3['Price_4']+
                  df_pa_segment_3['Price_5']
                  )/5

model_incidence_segment_3=LogisticRegression(solver='sag')
model_incidence_segment_3.fit(X3,Y3)

model_incidence_segment_3.coef_

Y_segment_3=model_incidence_segment_3.predict_proba(df_price_range)
purchase_pr_segment_3=Y_segment_3[:][:,1]
pe_segment_3=model_incidence_segment_3.coef_[:,0]*price_range*(1-purchase_pr_segment_3)

df_price_elasticities['PE_Segment_3']=pe_segment_3
df_price_elasticities
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
#      Price_Point   Mean_PE  PE_Segment_1  PE_Segment_2  PE_Segment_3
# 0           0.50 -0.096407     -0.119409     -0.030515     -0.168040
# 1           0.51 -0.100475     -0.123606     -0.032260     -0.172965
# 2           0.52 -0.104670     -0.127897     -0.034091     -0.177959
# 3           0.53 -0.108996     -0.132283     -0.036012     -0.183025
# 4           0.54 -0.113455     -0.136766     -0.038026     -0.188162
# 5           0.55 -0.118050     -0.141347     -0.040138     -0.193371
# 6           0.56 -0.122786     -0.146027     -0.042353     -0.198652
# 7           0.57 -0.127665     -0.150809     -0.044674     -0.204006
# 8           0.58 -0.132690     -0.155694     -0.047106     -0.209433
# 9           0.59 -0.137865     -0.160682     -0.049655     -0.214934
# 10          0.60 -0.143195     -0.165777     -0.052325     -0.220509
# 11          0.61 -0.148681     -0.170978     -0.055122     -0.226158
# 12          0.62 -0.154328     -0.176288     -0.058051     -0.231882
# 13          0.63 -0.160140     -0.181709     -0.061117     -0.237681
# 14          0.64 -0.166119     -0.187241     -0.064327     -0.243556
# 15          0.65 -0.172271     -0.192887     -0.067686     -0.249507
# 16          0.66 -0.178598     -0.198648     -0.071202     -0.255534
# 17          0.67 -0.185105     -0.204524     -0.074880     -0.261639
# 18          0.68 -0.191795     -0.210519     -0.078727     -0.267820
